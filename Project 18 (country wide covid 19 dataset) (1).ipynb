# %%
#Importing Libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading  database
df2=pd.read_csv('worldometer_snapshots_April18_to_May18.csv')
df2
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-18                 Russia   145927292    1831892.0      36793.0
# 2     2020-04-18                  Spain    46752703     930230.0     194416.0
# 3     2020-04-18                 Brazil   212380932      62985.0      36722.0
# 4     2020-04-18                     UK    67844241     460437.0     114217.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-18              St. Barth        9874          NaN          6.0
# 6599  2020-05-18         Western Sahara      595462          NaN          6.0
# 6600  2020-05-18               Anguilla       14987          NaN          3.0
# 6601  2020-05-18                Lesotho     2140235          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
#Loading  database
df3=pd.read_csv('population_structure_by_age_per_contry.csv')
df3
# Out:
#                    Country  Fraction age 0-14 years  Fraction age 15-64 years  \
# 0                      USA                    0.189                     0.657
# 1                   Russia                    0.176                     0.682
# 2                    Spain                    0.147                     0.659
# 3                   Brazil                    0.217                     0.697
# 4                       UK                    0.177                     0.638
# ..                     ...                      ...                       ...
# 208              St. Barth                      NaN                       NaN
# 209         Western Sahara                      NaN                       NaN
# 210               Anguilla                      NaN                       NaN
# 211                Lesotho                    0.354                     0.601
# 212  Saint Pierre Miquelon                      NaN                       NaN
#
#      Fraction age 65+ years
# ...

# %%
# Merging both database 
df = pd.merge(df2, df3)
df
# Out:
#             Date                Country  Population  Total Tests  Total Cases  \
# 0     2020-04-18                    USA   330774664    3722145.0     738792.0
# 1     2020-04-19                    USA   330774664    3861549.0     763832.0
# 2     2020-04-20                    USA   330774664    4026360.0     792759.0
# 3     2020-04-21                    USA   330774664    4187392.0     818744.0
# 4     2020-04-22                    USA   330774664    4325342.0     848717.0
# ...          ...                    ...         ...          ...          ...
# 6598  2020-05-14  Saint Pierre Miquelon        5797          NaN          1.0
# 6599  2020-05-15  Saint Pierre Miquelon        5797          NaN          1.0
# 6600  2020-05-16  Saint Pierre Miquelon        5797          NaN          1.0
# 6601  2020-05-17  Saint Pierre Miquelon        5797          NaN          1.0
# 6602  2020-05-18  Saint Pierre Miquelon        5797          NaN          1.0
#
# ...

# %%
# Name of the columns
df.columns
# Out:
# Index(['Date', 'Country', 'Population', 'Total Tests', 'Total Cases',
#        'Total Deaths', 'Total Recovered', 'Serious or Critical',
#        'Active Cases', 'Fraction age 0-14 years', 'Fraction age 15-64 years',
#        'Fraction age 65+ years'],
#       dtype='object')

# %%
# Shape of the database 
df.shape
# Out:
# (6603, 12)

# %%
#information of the database
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6603 entries, 0 to 6602
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      6603 non-null   object
#  1   Country                   6603 non-null   object
#  2   Population                6603 non-null   int64
#  3   Total Tests               5505 non-null   float64
#  4   Total Cases               6554 non-null   float64
#  5   Total Deaths              5367 non-null   float64
#  6   Total Recovered           6318 non-null   float64
#  7   Serious or Critical       4117 non-null   float64
#  8   Active Cases              6544 non-null   float64
#  9   Fraction age 0-14 years   5456 non-null   float64
#  10  Fraction age 15-64 years  5456 non-null   float64
#  11  Fraction age 65+ years    5456 non-null   float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 670.6+ KB

# %%
#datatypes
df.dtypes
# Out:
# Date                         object
# Country                      object
# Population                    int64
# Total Tests                 float64
# Total Cases                 float64
# Total Deaths                float64
# Total Recovered             float64
# Serious or Critical         float64
# Active Cases                float64
# Fraction age 0-14 years     float64
# Fraction age 15-64 years    float64
# Fraction age 65+ years      float64
# dtype: object

# %%
df.describe()
# Out:
#          Population   Total Tests   Total Cases  Total Deaths  \
# count  6.603000e+03  5.505000e+03  6.554000e+03   5367.000000
# mean   3.637913e+07  2.167252e+05  1.692968e+04   1416.252096
# std    1.411537e+08  7.595143e+05  8.861467e+04   6645.247810
# min    8.010000e+02  1.000000e+01  1.000000e+00      0.000000
# 25%    8.672680e+05  2.690000e+03  7.900000e+01      6.000000
# 50%    6.859926e+06  2.547800e+04  6.135000e+02     24.000000
# 75%    2.546422e+07  1.437810e+05  4.877500e+03    199.000000
# max    1.439324e+09  1.230074e+07  1.550294e+06  91981.000000
#
#        Total Recovered  Serious or Critical  Active Cases  \
# count      6318.000000          4117.000000  6.544000e+03
# mean       5855.424185           386.748360  9.964142e+03
# std       23467.641235          1658.428324  6.541025e+04
# min           1.000000             1.000000  0.000000e+00
# 25%          26.000000             3.000000  2.600000e+01
# ...

# %%
# Making  heatmap of describe.
plt.figure(figsize=(8,5))
sns.heatmap(df.describe())

# %%
#Finding Correlation of the variables
df.corr()
# Out:
#                           Population  Total Tests  Total Cases  Total Deaths  \
# Population                  1.000000     0.307950     0.225890      0.177861
# Total Tests                 0.307950     1.000000     0.900321      0.811128
# Total Cases                 0.225890     0.900321     1.000000      0.934705
# Total Deaths                0.177861     0.811128     0.934705      1.000000
# Total Recovered             0.309692     0.825681     0.829137      0.840124
# Serious or Critical         0.231260     0.744832     0.890988      0.829517
# Active Cases                0.179400     0.859148     0.977766      0.892579
# Fraction age 0-14 years    -0.039907    -0.218434    -0.170213     -0.183683
# Fraction age 15-64 years    0.071563     0.112653     0.076647      0.040350
# Fraction age 65+ years     -0.007370     0.235841     0.209377      0.262459
#
#                           Total Recovered  Serious or Critical  Active Cases  \
# ...

# %%
#finding null values in the database
df.isnull().sum()
# Out:
# Date                           0
# Country                        0
# Population                     0
# Total Tests                 1098
# Total Cases                   49
# Total Deaths                1236
# Total Recovered              285
# Serious or Critical         2486
# Active Cases                  59
# Fraction age 0-14 years     1147
# Fraction age 15-64 years    1147
# Fraction age 65+ years      1147
# dtype: int64

# %%
# Filling nan values with 0
df.dropna(how= 'any', inplace= True)

# %%
#finding null values in the database
df.isnull().sum()
# Out:
# Date                        0
# Country                     0
# Population                  0
# Total Tests                 0
# Total Cases                 0
# Total Deaths                0
# Total Recovered             0
# Serious or Critical         0
# Active Cases                0
# Fraction age 0-14 years     0
# Fraction age 15-64 years    0
# Fraction age 65+ years      0
# dtype: int64

# %%
df
# Out:
#             Date Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0     2020-04-18     USA   330774664    3722145.0     738792.0       39014.0
# 1     2020-04-19     USA   330774664    3861549.0     763832.0       40553.0
# 2     2020-04-20     USA   330774664    4026360.0     792759.0       42514.0
# 3     2020-04-21     USA   330774664    4187392.0     818744.0       45318.0
# 4     2020-04-22     USA   330774664    4325342.0     848717.0       47659.0
# ...          ...     ...         ...          ...          ...           ...
# 5840  2020-04-30  Belize      396732        995.0         18.0           2.0
# 5841  2020-05-01  Belize      396732       1043.0         18.0           2.0
# 5842  2020-05-02  Belize      396732       1043.0         17.0           2.0
# 5843  2020-05-03  Belize      396732       1043.0         18.0           2.0
# 5844  2020-05-04  Belize      396732       1043.0         18.0           2.0
#
# ...

# %%
# Spliting  Date column into DATE , Month , Year column.
df['Year'] = df['Date'].str.split("-").str[0]
df['Month'] =df['Date'].str.split('-').str[1]
df['DATE'] =df['Date'].str.split('-').str[2]

# %%
# Droping Date column.
df=df.drop(['Date'],axis=1)
df
# Out:
#      Country  Population  Total Tests  Total Cases  Total Deaths  \
# 0        USA   330774664    3722145.0     738792.0       39014.0
# 1        USA   330774664    3861549.0     763832.0       40553.0
# 2        USA   330774664    4026360.0     792759.0       42514.0
# 3        USA   330774664    4187392.0     818744.0       45318.0
# 4        USA   330774664    4325342.0     848717.0       47659.0
# ...      ...         ...          ...          ...           ...
# 5840  Belize      396732        995.0         18.0           2.0
# 5841  Belize      396732       1043.0         18.0           2.0
# 5842  Belize      396732       1043.0         17.0           2.0
# 5843  Belize      396732       1043.0         18.0           2.0
# 5844  Belize      396732       1043.0         18.0           2.0
#
#       Total Recovered  Serious or Critical  Active Cases  \
# 0             68269.0              13551.0      631509.0
# 1             71003.0              13566.0      652276.0
# ...

# %%
datasorted=df.groupby("Country").mean()
datasorted=datasorted.sort_values("Total Cases",ascending=False)

# %%
datasorted
# Out:
#                      Population   Total Tests   Total Cases  Total Deaths  \
# Country
# USA                   330774664  7.483887e+06  1.167629e+06  67819.129032
# Spain                  46752703  1.795037e+06  2.434831e+05  24751.774194
# Italy                  60471924  2.159510e+06  2.069946e+05  28441.903226
# France                 65256826  9.517897e+05  1.690009e+05  24572.903226
# Germany                83752855  2.497693e+06  1.639101e+05   6717.548387
# ...                         ...           ...           ...           ...
# Barbados                 287335  2.354355e+03  8.116129e+01      6.516129
# Malawi                 19066433  9.536774e+02  4.241935e+01      2.870968
# Antigua and Barbuda       97833  1.412903e+02  2.445161e+01      3.000000
# Grenada                  112462  1.406000e+03  2.100000e+01      0.000000
# Belize                   396732  8.772500e+02  1.793750e+01      2.000000
#
# ...

# %% [markdown]
# # Visualization

# %%
# barplot of Population in different country.
plt.figure(figsize=(40,20))
sns.barplot(x=datasorted.index,y=datasorted["Population"])
plt.xticks(rotation= 90)
plt.xlabel('States', size= 20)
plt.ylabel('Total Cases' , size= 20)
plt.title('' , size= 20)
# Conclusion:- China has maximum population.
# Out:
# Text(0.5, 1.0, '')

# %%
# barplot of Total Cases in different country.
plt.figure(figsize=(40,20))
sns.barplot(x=datasorted.index,y=datasorted["Total Cases"])
plt.xticks(rotation= 90)
plt.xlabel('States', size= 20)
plt.ylabel('Total Cases' , size= 20)
plt.title('' , size= 20)
# Conclusion:- USA has maximum number of cases.
# Out:
# Text(0.5, 1.0, '')

# %%
# barplot of Total Deaths in different country.
plt.figure(figsize=(40,20))
sns.barplot(x=datasorted.index,y=datasorted["Total Deaths"])
plt.xticks(rotation= 90)
plt.xlabel('Country', size= 20)
plt.ylabel('Total Deaths' , size= 20)
plt.title('' , size= 20)
# Conclusion:- USA has maximum Deaths.
# Out:
# Text(0.5, 1.0, '')

# %%
# barplot of Total Recovered in different country.
plt.figure(figsize=(40,20))
sns.barplot(x=datasorted.index,y=datasorted["Total Recovered"])
plt.xticks(rotation= 90)
plt.xlabel('Country', size= 20)
plt.ylabel('Total Recovered' , size= 20)
plt.title('' , size= 20)
#Conclusion:-  USA has maximum recovered numbers.
# Out:
# Text(0.5, 1.0, '')

# %%
# barplot of Active Cases  in different country.
plt.figure(figsize=(40,20))
sns.barplot(x=datasorted.index,y=datasorted["Active Cases"])
plt.xticks(rotation= 90)
plt.xlabel('Country', size= 20)
plt.ylabel('Active Cases' , size= 20)
plt.title('' , size= 20)
# USA has most active cases of covid.
# Out:
# Text(0.5, 1.0, '')

# %%
# Making Histrogram of all variables
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2AFE73088>,
# ...
#       dtype=object)

# %%
# Making Boxplot of all variables 
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(25,25))
# Out:
# Population                      AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Tests                  AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Cases                   AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# Total Deaths                 AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Total Recovered              AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Serious or Critical            AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Active Cases                AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Fraction age 0-14 years      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Fraction age 15-64 years    AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# Fraction age 65+ years      AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# dtype: object

# %%
#Using Label Encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
list1=['Country' ,'Year'
]
for val in list1:
     df[val]=le.fit_transform(df[val].astype(str))

# %% [markdown]
# # Splitting Data into target and Input

# %%
x=df.drop(['Total Deaths'],axis=1)
x
# Out:
#       Country  Population  Total Tests  Total Cases  Total Recovered  \
# 0          20   330774664    3722145.0     738792.0          68269.0
# 1          20   330774664    3861549.0     763832.0          71003.0
# 2          20   330774664    4026360.0     792759.0          72389.0
# 3          20   330774664    4187392.0     818744.0          82923.0
# 4          20   330774664    4325342.0     848717.0          84050.0
# ...       ...         ...          ...          ...              ...
# 5840       32      396732        995.0         18.0              9.0
# 5841       32      396732       1043.0         18.0             13.0
# 5842       32      396732       1043.0         17.0             13.0
# 5843       32      396732       1043.0         18.0             13.0
# 5844       32      396732       1043.0         18.0             13.0
#
#       Serious or Critical  Active Cases  Fraction age 0-14 years  \
# 0                 13551.0      631509.0                    0.189
# ...

# %%
y=df["Total Deaths"]
y
# Out:
# 0       39014.0
# 1       40553.0
# 2       42514.0
# 3       45318.0
# 4       47659.0
#          ...
# 5840        2.0
# 5841        2.0
# 5842        2.0
# 5843        2.0
# 5844        2.0
# Name: Total Deaths, Length: 3242, dtype: float64

# %%
# standard scaling data 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(x))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x.skew()
# Out:
# Country                     0.038872
# Population                  2.993683
# Total Tests                 6.899586
# Total Cases                 8.789401
# Total Recovered             5.326932
# Serious or Critical         6.479425
# Active Cases                9.589984
# Fraction age 0-14 years     0.980357
# Fraction age 15-64 years    0.335948
# Fraction age 65+ years      0.213082
# Year                        0.000000
# Month                      -0.347027
# DATE                       -0.014814
# dtype: float64

# %%
#Reducing  Skewness
import numpy as np
for col in x.columns:
    if x.skew().loc[col]>0.55:
         x[col]=np.log1p(x[col])

# %%
x.skew()
# Out:
# Country                     0.038872
# Population                 -0.305631
# Total Tests                -0.505889
# Total Cases                 0.067799
# Total Recovered             0.122403
# Serious or Critical         0.705786
# Active Cases               -0.118272
# Fraction age 0-14 years     0.856785
# Fraction age 15-64 years    0.335948
# Fraction age 65+ years      0.213082
# Year                        0.000000
# Month                      -0.347027
# DATE                       -0.014814
# dtype: float64

# %% [markdown]
# # Importing Necessary libraries

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression

# %%
def maxr2_score(regr,x,y):
    max_r_score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state= i ,test_size=0.20)
        regr.fit(x,y)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_i=i
    print(" We are getting maximum  r2 score corresponding to",final_i,"is",max_r_score)
    return final_i

# %% [markdown]
# # Finding Best random state of different algorithim

# %%
# using Grid search CV to find best  parameters of different algorithim .
knn=KNeighborsRegressor()
parameters={"n_neighbors" :(5,20) , 'algorithm' :['auto', 'ball_tree', 'kd_tree', 'brute']}
gd=GridSearchCV(knn,parameters)
gd.fit(x,y)
print(" Best parameters of KNeighborsRegressor is :-")
print(gd.best_params_)
print("\n")

lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1] , 'selection' : ['cyclic', 'random']}
gd=GridSearchCV(lsreg,parameters)
gd.fit(x,y)
print(" Best parameters of Lasso is :-")
print(gd.best_params_)
print("\n")

dtc=DecisionTreeRegressor()
parameters={"criterion" :( 'mse', 'friedman_mse', 'mae') ,'max_features' : ['auto', 'sqrt', 'log2']}
gd=GridSearchCV(dtc,parameters)
gd.fit(x,y)
print(" Best parameters of DecisionTreeRegressor is :-")
print(gd.best_params_)
print("\n")


#Best parameters for  AdaBoostRegressor
ada=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[25,50,100,150,200]}
gd=GridSearchCV(ada,parameters)
gd.fit(x,y)
print(" Best parameters of AdaBoostRegressor is :-")
print(gd.best_params_)
print("\n")
# Out:
#  Best parameters of KNeighborsRegressor is :-
# {'algorithm': 'auto', 'n_neighbors': 5}
#
#
#  Best parameters of Lasso is :-
# {'alpha': 0.001, 'selection': 'cyclic'}
#
#
#  Best parameters of DecisionTreeRegressor is :-
# {'criterion': 'friedman_mse', 'max_features': 'auto'}
#
#
#  Best parameters of AdaBoostRegressor is :-
# {'learning_rate': 0.001, 'n_estimators': 50}

# %%
# Finding best r2 score value for Linear Regression 
print("Linear Regression")
print("................. ")
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Linear Regression:",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("standard deviation in r2 score for Linear Regression",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print(" ")
print("#############################################################################")
print(" ")


# Finding best r2 score value for KNeighbors regressor 
print("KNeighbors regressor ")
print("..................... ")
knn=KNeighborsRegressor(n_neighbors= 5 , algorithm = 'auto')
i=maxr2_score(knn,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for KNeighbor  Regression:",cross_val_score(knn,x,y,cv=135,scoring="r2").mean())
print("standard deviation in r2 score for KNeighbor   Regression",cross_val_score(knn,x,y,cv=5,scoring="r2").std())
print(" ")
print("##############################################################################")
print(" ")

# Finding best r2 score value for Lasso Regressor 
print("Lasso Regressor")
print("................ ")
lsreg=Lasso(alpha=0.001 , selection = 'cyclic')
i=maxr2_score(lsreg,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for Lasso Regression:",cross_val_score(lsreg,x,y,cv=63,scoring="r2").mean())
print("standard deviation in r2 score for Lasso Regression",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
print(" ")
print("################################################################################")
print(" ")

# Finding best r2 score value for DecisionTreeRegressor
print("DecisionTreeRegressor")
print("...................... ")
dtc=DecisionTreeRegressor(criterion = 'friedman_mse'  , max_features = 'auto')
i=maxr2_score(dtc,x,y)
print(" ")
from sklearn.model_selection import cross_val_score
print("Mean r2 score for DecisionTreeRegressor :",cross_val_score(dtc,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for DecisionTreeRegressor",cross_val_score(dtc,x,y,cv=5,scoring="r2").std())
print(" ")
print("#################################################################################")
print(" ")


# Finding best r2 score value for  AdaBoostRegressor
print("AdaBoostRegressor")
print(".................. ")
ada=AdaBoostRegressor(n_estimators=50 , learning_rate = 0.001)
i=maxr2_score(ada,x,y)
print(" ")
print("Mean r2 score for AdaBoostRegressor :",cross_val_score(ada,x,y,cv=10,scoring="r2").mean())
print("standard deviation in r2 score for AdaBoostRegressor ",cross_val_score(ada,x,y,cv=5,scoring="r2").std())
print(" ")
print("#####################################################################################")
# Out:
# Linear Regression
# .................
#  We are getting maximum  r2 score corresponding to 64 is 0.3368410925605485
#
# Mean r2 score for Linear Regression: -263469.7013676731
# standard deviation in r2 score for Linear Regression 524543.001394284
#
# #############################################################################
#
# KNeighbors regressor
# .....................
#  We are getting maximum  r2 score corresponding to 73 is 0.9997266312487464
#
# Mean r2 score for KNeighbor  Regression: -131.58929848898723
# standard deviation in r2 score for KNeighbor   Regression 7.954118455065829
#
# ##############################################################################
#
# Lasso Regressor
# ................
#  We are getting maximum  r2 score corresponding to 64 is 0.3365698416726015
#
# Mean r2 score for Lasso Regression: -3000327.794462584
# standard deviation in r2 score for Lasso Regression 527204.110755136
#
# ...

# %% [markdown]
# # Since Decision Tree regressor is giving better result so we choose it has final model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
dtc=DecisionTreeRegressor(criterion = 'friedman_mse'  , max_features = 'auto')
dtc.fit(x,y)
y_pred=dtc.predict(x_test)

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is:",r2_score(y_test,y_pred))
# Out:
# RMSE is:  0.0
# r2_score is: 1.0

# %% [markdown]
# # Saving the model

# %%
from sklearn.externals import joblib
joblib.dump(dtc,"covid45.pkl")
# Out:
# ['covid45.pkl']
